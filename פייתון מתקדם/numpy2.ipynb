# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.4 MB 4.0 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/12.4 MB 4.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.4 MB 4.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.4 MB 3.8 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.4 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.4 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.4 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.4 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.4 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.4 MB 4.4 MB/s eta 0:00:01
# ...

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50, size=(10,1))
random_int_array
# Out:
# array([[13],
#        [18],
#        [39],
#        [30],
#        [17],
#        [26],
#        [ 7],
#        [46],
#        [45],
#        [25]], dtype=int32)

# %% [markdown]
# ex1

# %%
random_int_array.dtype
# Out:
# dtype('int32')

# %%
np.ndim(random_int_array)
# Out:
# 2

# %%
random_int_array.shape
# Out:
# (10, 1)

# %%
random_int_array.size
# Out:
# 10

# %% [markdown]
# ex2

# %%
matrix=np.random.randint(10, 100, size=(2,5))

# %%
matrix
# Out:
# array([[69, 89, 61, 88, 21],
#        [31, 33, 63, 28, 14]], dtype=int32)

# %%
matrix.shape
# Out:
# (2, 5)

# %% [markdown]
# ex2

# %%
arr1=np.array([[1,5,9],[1,5,9]])

# %%
arr1
# Out:
# ([1, 5, 9], [1, 5, 9], [1, 5, 9])

# %%
arr2=np.array([[1,5,9],[1,5,9]])

# %%
arr3=arr1+arr2

# %%
arr3
# Out:
# array([[ 2, 10, 18],
#        [ 2, 10, 18]])

# %%
np.median(arr3)
# Out:
# np.float64(10.0)

# %% [markdown]
# ex3

# %%
arr=np.random.randint(1, 100, size=20)

# %%
arr
# Out:
# array([ 5, 81, 81,  4, 37, 66, 89, 40, 10, 64, 29, 69, 74, 13, 25, 32, 62,
#        61, 15, 18], dtype=int32)

# %%
condition = arr > 50
filtered_arr = arr[condition]
filtered_arr
# Out:
# array([81, 81, 66, 89, 64, 69, 74, 62, 61], dtype=int32)

# %% [markdown]
# ex4

# %%
numbers = list(range(1, 11))

# %%
import random

# %%
random.shuffle(numbers)

# %%
numbers
# Out:
# [8, 1, 6, 10, 9, 5, 3, 7, 2, 4]
